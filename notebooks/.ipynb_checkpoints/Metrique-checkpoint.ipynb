# %%
from metrique_stats import stats
from metrique_stats import stats_class
# %matplotlib inline

# %%
g = stats.init_neo_graph()

query = "MATCH (n)-->(m) RETURN n as source, m as target"
ig = stats.neo_to_igraph(query, g, directed=False)
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-2-b2a8d7646870> in <module>()
#       2
#       3 query = "MATCH (n)-->(m) RETURN n as source, m as target"
# ----> 4 ig = stats.neo_to_igraph(query,g, directed=False)
#
# /app/notebooks/metrique_stats/stats.py in neo_to_igraph(query, graph, directed)
#      29     """
#      30
# ---> 31     data = graph.cypher.execute(query)
#      32     ig = IGraph.TupleList(data, directed)
#      33
#
# /usr/local/lib/python3.4/site-packages/py2neo/core.py in cypher(self)
#     666             from py2neo.cypher import CypherResource
#     667             metadata = self.resource.metadata
# --> 668             self.__cypher = CypherResource(metadata["cypher"], metadata.get("transaction"))
#     669         return self.__cypher
#     670
#
# KeyError: 'cypher'

# %%
ds = stats.degree_stats(ig)
ds.print()
# Out:
# Number of vertices =  0
# Number of edges =  0
# Average degree =  0.0
# Max degree =  0

# %%
ps = stats.path_stats(ig)
ps.print()
# Out:
# Characteristic Path Length :  nan

# %%
es = stats.ecc_stats(ig)
es.print()
# Out:
# Average Eccentricity =  7.456140350877191
# Radius =  5.0
# Diameter =  10

# %%
cs = stats.connect_stats(ig)
cs.print()
# Out:
# Number of Connected Components =  1
# Vertex connectivity =  1
# Edge connectivity =  1
# Number of BiConnected Components =  87

# %%
cls = stats.cluster_stats(ig)
cls.print()
# Out:
# Number of triangles =  3
# Number of Clusters =  1
# Graph Clustering Coefficient =  0.008946322067594433

# %%
ces = stats.central_stats(ig)
ces.print()
