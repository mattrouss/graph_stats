# %%
from metrique_stats import stats
from metrique_stats import stats_class
# %matplotlib inline

# %%
#from py2neo import Graph, authenticate
#authenticate("http://simulab.li.kernix.net:7475", "neo4j", "pass4dbse")
#graph = Graph("http://neo4j:pass4dbse@simulab.li.kernix.net:7475/db/data/")
#data = graph.cypher.execute(query)
#data
#ig = IGraph.TupleList(data, directed)


query = "MATCH (n)-->(m) RETURN n as source, m as target"

#g = stats.init_neo_graph("http://simulab.li.kernix.net:7475", "neo4j", "pass4dbse")
g = stats.init_neo_graph("http://neo:7474/db/data")
ig = stats.neo_to_igraph(query, g, directed=False)

# %%
ds = stats.degree_stats(ig)
ds.print()
# Out:
# Number of vertices =  85
# Number of edges =  767
# Average degree =  18.047058823529408
# Max degree =  33

# %%
ps = stats.path_stats(ig)
ps.print()
# Out:
# Characteristic Path Length :  1.957422969187675

# %%
es = stats.ecc_stats(ig)
es.print()
# Out:
# Average Eccentricity =  3.1529411764705877
# Radius =  2.0
# Diameter =  4

# %%
cs = stats.connect_stats(ig)
cs.print()
# Out:
# Number of Connected Components =  1
# Vertex connectivity =  1
# Edge connectivity =  1
# Number of BiConnected Components =  3

# %%
cls = stats.cluster_stats(ig)
cls.print()
# Out:
# Number of triangles =  1058
# Graph Clustering Coefficient =  0.2070450097847358

# %%
ces = stats.central_stats(ig)
ces.print()
